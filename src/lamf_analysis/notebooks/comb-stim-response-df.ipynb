# %%
from comb.behavior_ophys_dataset import BehaviorOphysDataset
from brain_observatory_utilities.datasets.optical_physiology.data_formatting import build_tidy_cell_df, get_stimulus_response_df

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# define inputs

data_folder = Path("/root/capsule/data/") # Note: full path, glob doesn't like ~
processed_path = data_folder / "multiplane-ophys_677594_2023-08-04_09-44-08_processed_2024-02-08_23-26-44"
plane_folder_path = processed_path / "1287841795" # 1 of 8 possible planes
raw_path = data_folder / "multiplane-ophys_677594_2023-08-04_09-44-08"

# %%
bod = BehaviorOphysDataset(plane_folder_path, raw_path, verbose=True)
# Out:
# _platform.json: 1287841795/1287701514_platform.json
# processing.json: 1287841795/processing.json
# _params.json: events/1287841795_params.json
# _registered_metrics.json: movie_qc/1287841795_registered_metrics.json
# _output.json: segmentation/segmentation_output.json
# _average_projection.png: motion_correction/1287841795_average_projection.png
# _max_projection.png: not found
# _motion_transform.csv: motion_correction/1287841795_motion_transform.csv
# segmentation_output.json: segmentation/segmentation_output.json
# roi_traces.h5: trace_extraction/roi_traces.h5
# neuropil_correction.h5: neuropil_correction/neuropil_correction.h5
# neuropil_masks.json: trace_extraction/neuropil_masks.json
# neuropil_trace_output.json: neuropil_correction/neuropil_trace_output.json
# demixing_output.h5: demixing/demixing_output.h5
# demixing_output.json: demixing/demixing_output.json
# dff.h5: dff/dff.h5
# extract_traces.json: trace_extraction/extract_traces.json
# events_oasis.h5: events/1287841795_events_oasis.h5
# MESOSCOPE_FILE_SPLITTING: 1287841795/MESOSCOPE_FILE_SPLITTING_QUEUE_1287701514_input.json
# Currently sync file stored in raw data assest, will load since raw_folder_path is provided (02/01/2024)
# [0, 10, 11, 50, 60, 67, 74, 86, 87, 88, 9]
# Index(['x', 'y', 'width', 'height', 'mask_matrix', 'valid_roi',
#        'mask_image_plane', 'exclusion_labels', 'cell_roi_id',
#        'max_correction_up', 'max_correction_down', 'max_correction_left',
#        'max_correction_right'],
#       dtype='object')
# Set 11 cell_specimen_ids to invalid_roi, found all nan traces
# ophys_timestamps: 171308 -> 42827 (resampled for mesoscope data)
# Calculating frame rate from ophys_timestamps, not metadata

# %%
# %matplotlib inline
tidy_dff = build_tidy_cell_df(bod)


# plot 1 trace
trace = tidy_dff[tidy_dff.cell_roi_id==1].dff
plt.plot(trace.values)
plt.show()

# %%
sdf = get_stimulus_response_df(bod, data_type='dff', event_type='changes',
                               time_window=[-1, 2.1], interpolate=False,
                               output_sampling_rate=None,
                               response_window_duration=0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'is_change'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /ophys-mfish-dev/ophys-mfish-dev/notebooks/comb-stim-response-df.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell://codeocean.allenneuraldynamics.org/ophys-mfish-dev/ophys-mfish-dev/notebooks/comb-stim-response-df.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> sdf = get_stimulus_response_df(bod, data_type='dff', event_type='changes',
#       <a href='vscode-notebook-cell://codeocean.allenneuraldynamics.org/ophys-mfish-dev/ophys-mfish-dev/notebooks/comb-stim-response-df.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>                                time_window=[-1, 2.1], interpolate=False,
#       <a href='vscode-notebook-cell://codeocean.allenneuraldynamics.org/ophys-mfish-dev/ophys-mfish-dev/notebooks/comb-stim-response-df.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>                                output_sampling_rate=None,
#       <a href='vscode-notebook-cell://codeocean.allenneuraldynamics.org/ophys-mfish-dev/ophys-mfish-dev/notebooks/comb-stim-response-df.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>                                response_window_duration=0.5)
#
# File /brain_observatory_utilities/brain_observatory_utilities/datasets/optical_physiology/data_formatting.py:492, in get_stimulus_response_df(ophys_experiment, data_type, event_type, time_window, response_window_duration, interpolate, output_sampling_rate, exclude_invalid_rois, **kwargs)
#     438 def get_stimulus_response_df(ophys_experiment,
#     439                              data_type='dff',
#     440                              event_type='all',
#    (...)
#     445                              exclude_invalid_rois=True,
#     446                              **kwargs):
#     447     '''
#     448     Get stimulus aligned responses from one ophys_experiment.
#     449
#    (...)
#     489
#     490     '''
# --> 492     stimulus_response_xr = get_stimulus_response_xr(
#     493         ophys_experiment=ophys_experiment,
#     494         data_type=data_type,
#     495         event_type=event_type,
#     496         time_window=time_window,
#     497         response_window_duration=response_window_duration,
#     498         interpolate=interpolate,
#     499         output_sampling_rate=output_sampling_rate,
#     500         exclude_invalid_rois=exclude_invalid_rois,
#     501         **kwargs)
#     503     # set up identifier columns depending on whether behavioral or neural data is being used
#     504     # if (data_type == 'running_speed') or (data_type == 'pupil_diameter') or (data_type == 'lick_rate'):
#     505     if ('lick' in data_type) or ('pupil' in data_type) or ('running' in data_type):
#     506         # set up variables to handle only one timeseries per event instead of multiple cell_specimen_ids
#
# File /brain_observatory_utilities/brain_observatory_utilities/datasets/optical_physiology/data_formatting.py:182, in get_stimulus_response_xr(ophys_experiment, data_type, event_type, time_window, response_window_duration, interpolate, output_sampling_rate, exclude_invalid_rois, **kwargs)
#     179 stimulus_presentations = ophys_experiment.stimulus_presentations
#     181 # get event times and event ids (original order in the stimulus flow)
# --> 182 event_times, event_ids = get_event_timestamps(
#     183     stimulus_presentations, event_type)
#     185 if ('running' in data_type) or ('pupil' in data_type) or ('lick' in data_type):
#     186     # for behavioral datastreams
#     187     # set up variables to handle only one timeseries per event instead of multiple cell_specimen_ids
#     188     unique_id_string = 'trace_id'  # create a column to take the place of 'cell_specimen_id'
#
# File /brain_observatory_utilities/brain_observatory_utilities/datasets/optical_physiology/data_formatting.py:112, in get_event_timestamps(stimulus_presentation, event_type, onset)
#     110     event_ids = stimulus_presentation[stimulus_presentation['omitted']].index.values  # noqa E501
#     111 elif event_type == 'changes' or event_type == 'is_change':
# --> 112     event_times = stimulus_presentation[stimulus_presentation['is_change']][onset]  # noqa E501
#     113     event_ids = stimulus_presentation[stimulus_presentation['is_change']].index.values  # noqa E501
#     114 else:
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'is_change'

# %%
traces = np.vstack(sdf.trace.values)
mean_trace = np.nanmean(traces, axis=0)

plt.plot(mean_trace)
plt.xlabel('2P frames')
plt.ylabel('dF/F')
plt.title('population response to omission')
plt.show()
